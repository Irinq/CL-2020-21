# %% [markdown]
# с помощью словаря создайте простой транслитератор: нужно, чтобы программа принимала с клавиатуры (у нас есть специальный оператор ввода с клавиатуры) слова, записанные кириллицей, и печатала результат латиницей.
#
# Пример: собака >> sobaka

# %%
# Успела только поменять буквы, не успела придумать, как красиво вывести результат :(
    
cyrillic = {'а': "a", 'б': "b","в":"v","г":"g","д":"d", "е":"e", "ё":"yo", "ж":"zh", "з":"z", 
     "и":"i", "й":"y", "к":"k", "л":"l", "м":"m", "н":"n", "о":"o", "п":"p",
     "р":"r", "с":"s", "т":"t", "у":"u", "ф":"f", "х":"h", "ц":"ts", "ц":"tsh", "ш":"sh", 
     "щ":"tsch", "э":"e", "ю":"yu", "я":"ya", "ъ":"y", "ь":"\'"}
word = list(input())
for letter in word:
  if letter in cyrillic:
    letter = d.get(letter)
    print(letter)
  else: print('Так нельзя, пишите кириллицей!')
  break
